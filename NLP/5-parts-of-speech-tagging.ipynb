# %%
import nltk

# %%
paragraph = '''Machine learning is evolving fast. Models learn from data. Engineers clean the text carefully. They remove stopwords first. They normalize the words next. Some words are playing. Others were played earlier. People study models daily. They studied them yesterday. Systems are running now. Some systems ran before. Accuracy improves slowly. Better features help models. Good preprocessing matters a lot.'''

# %%
sentences = nltk.sent_tokenize(paragraph)
sentences
# Out:
# ['Machine learning is evolving fast.',
#  'Models learn from data.',
#  'Engineers clean the text carefully.',
#  'They remove stopwords first.',
#  'They normalize the words next.',
#  'Some words are playing.',
#  'Others were played earlier.',
#  'People study models daily.',
#  'They studied them yesterday.',
#  'Systems are running now.',
#  'Some systems ran before.',
#  'Accuracy improves slowly.',
#  'Better features help models.',
#  'Good preprocessing matters a lot.']

# %%
for sentence in sentences: 
    words = nltk.word_tokenize(sentence)
    tagged = nltk.pos_tag(words) # gives a POS tag to each word
    print(tagged)
# Out:
# [('Machine', 'NN'), ('learning', 'NN'), ('is', 'VBZ'), ('evolving', 'VBG'), ('fast', 'RB'), ('.', '.')]
# [('Models', 'NNS'), ('learn', 'VBP'), ('from', 'IN'), ('data', 'NNS'), ('.', '.')]
# [('Engineers', 'NNS'), ('clean', 'VBP'), ('the', 'DT'), ('text', 'NN'), ('carefully', 'RB'), ('.', '.')]
# [('They', 'PRP'), ('remove', 'VBP'), ('stopwords', 'NNS'), ('first', 'RB'), ('.', '.')]
# [('They', 'PRP'), ('normalize', 'VBP'), ('the', 'DT'), ('words', 'NNS'), ('next', 'IN'), ('.', '.')]
# [('Some', 'DT'), ('words', 'NNS'), ('are', 'VBP'), ('playing', 'VBG'), ('.', '.')]
# [('Others', 'NNS'), ('were', 'VBD'), ('played', 'VBN'), ('earlier', 'RBR'), ('.', '.')]
# [('People', 'NNS'), ('study', 'VBP'), ('models', 'NNS'), ('daily', 'RB'), ('.', '.')]
# [('They', 'PRP'), ('studied', 'VBD'), ('them', 'PRP'), ('yesterday', 'NN'), ('.', '.')]
# [('Systems', 'NNS'), ('are', 'VBP'), ('running', 'VBG'), ('now', 'RB'), ('.', '.')]
# [('Some', 'DT'), ('systems', 'NNS'), ('ran', 'VBD'), ('before', 'IN'), ('.', '.')]
# [('Accuracy', 'NNP'), ('improves', 'VBZ'), ('slowly', 'RB'), ('.', '.')]
# [('Better', 'NNP'), ('features', 'NNS'), ('help', 'VBP'), ('models', 'NNS'), ('.', '.')]
# [('Good', 'JJ'), ('preprocessing', 'NN'), ('matters', 'NNS'), ('a', 'DT'), ('lot', 'NN'), ('.', '.')]

# %%
# apply POS tagging to an Individual sentence
sentence = "Careful preprocessing of text data makes machine learning models more accurate and easier to understand"

words = sentence.split(" ")
nltk.pos_tag(words)
# Out:
# [('Careful', 'JJ'),
#  ('preprocessing', 'NN'),
#  ('of', 'IN'),
#  ('text', 'JJ'),
#  ('data', 'NNS'),
#  ('makes', 'VBZ'),
#  ('machine', 'NN'),
#  ('learning', 'VBG'),
#  ('models', 'NNS'),
#  ('more', 'RBR'),
#  ('accurate', 'JJ'),
#  ('and', 'CC'),
#  ('easier', 'JJR'),
#  ('to', 'TO'),
#  ('understand', 'VB')]
