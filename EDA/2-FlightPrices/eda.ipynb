# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/economy.csv")
df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price
# 0  non-stop     21:05  Mumbai  5,953
# 1  non-stop     08:40  Mumbai  5,953
# 2  non-stop     06:35  Mumbai  5,956
# 3  non-stop     12:35  Mumbai  5,955
# 4  non-stop     11:10  Mumbai  5,955

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        206774 non-null  object
#  1   airline     206774 non-null  object
#  2   ch_code     206774 non-null  object
#  3   num_code    206774 non-null  int64
#  4   dep_time    206774 non-null  object
#  5   from        206774 non-null  object
#  6   time_taken  206774 non-null  object
#  7   stop        206774 non-null  object
#  8   arr_time    206774 non-null  object
#  9   to          206774 non-null  object
#  10  price       206774 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 17.4+ MB

# %%
df.describe() # mostly useless as num_code indicates flight number
# Out:
#             num_code
# count  206774.000000
# mean     1706.096714
# std      2320.463721
# min       101.000000
# 25%       588.000000
# 50%       818.000000
# 75%       960.000000
# max      9991.000000

# %%
df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price
# 0  non-stop     21:05  Mumbai  5,953
# 1  non-stop     08:40  Mumbai  5,953
# 2  non-stop     06:35  Mumbai  5,956
# 3  non-stop     12:35  Mumbai  5,955
# 4  non-stop     11:10  Mumbai  5,955

# %%
## Feature Engineering -- split date into day, month, year
df['day']=df['date'].str.split("-").str[0]
df['month']=df['date'].str.split("-").str[1]
df['year']=df['date'].str.split("-").str[2]

df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price day month  year
# 0  non-stop     21:05  Mumbai  5,953  11    02  2022
# 1  non-stop     08:40  Mumbai  5,953  11    02  2022
# 2  non-stop     06:35  Mumbai  5,956  11    02  2022
# 3  non-stop     12:35  Mumbai  5,955  11    02  2022
# 4  non-stop     11:10  Mumbai  5,955  11    02  2022

# %%
df['day'] = df['day'].astype(int)
df['month'] = df['month'].astype(int)
df['year'] = df['year'].astype(int)

# %%
df.head()
# Out:
#          date   airline ch_code  num_code dep_time   from time_taken  \
# 0  11-02-2022  SpiceJet      SG      8709    18:55  Delhi    02h 10m
# 1  11-02-2022  SpiceJet      SG      8157    06:20  Delhi    02h 20m
# 2  11-02-2022   AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  11-02-2022   Vistara      UK       995    10:20  Delhi    02h 15m
# 4  11-02-2022   Vistara      UK       963    08:50  Delhi    02h 20m
#
#         stop arr_time      to  price  day  month  year
# 0  non-stop     21:05  Mumbai  5,953   11      2  2022
# 1  non-stop     08:40  Mumbai  5,953   11      2  2022
# 2  non-stop     06:35  Mumbai  5,956   11      2  2022
# 3  non-stop     12:35  Mumbai  5,955   11      2  2022
# 4  non-stop     11:10  Mumbai  5,955   11      2  2022

# %%
# drop date column as it's no longer required

# %%
df.drop("date", axis=1, inplace=True)

# %%
df.head()
# Out:
#     airline ch_code  num_code dep_time   from time_taken       stop arr_time  \
# 0  SpiceJet      SG      8709    18:55  Delhi    02h 10m  non-stop     21:05
# 1  SpiceJet      SG      8157    06:20  Delhi    02h 20m  non-stop     08:40
# 2   AirAsia      I5       764    04:25  Delhi    02h 10m  non-stop     06:35
# 3   Vistara      UK       995    10:20  Delhi    02h 15m  non-stop     12:35
# 4   Vistara      UK       963    08:50  Delhi    02h 20m  non-stop     11:10
#
#        to  price  day  month  year
# 0  Mumbai  5,953   11      2  2022
# 1  Mumbai  5,953   11      2  2022
# 2  Mumbai  5,956   11      2  2022
# 3  Mumbai  5,955   11      2  2022
# 4  Mumbai  5,955   11      2  2022

# %%
df['arrival_hour'] = df['arr_time'].str.split(':').str[0]
df['arrival_minute'] = df['arr_time'].str.split(':').str[1]

# %%
df.head()
# Out:
#     airline ch_code  num_code dep_time   from time_taken       stop arr_time  \
# 0  SpiceJet      SG      8709    18:55  Delhi    02h 10m  non-stop     21:05
# 1  SpiceJet      SG      8157    06:20  Delhi    02h 20m  non-stop     08:40
# 2   AirAsia      I5       764    04:25  Delhi    02h 10m  non-stop     06:35
# 3   Vistara      UK       995    10:20  Delhi    02h 15m  non-stop     12:35
# 4   Vistara      UK       963    08:50  Delhi    02h 20m  non-stop     11:10
#
#        to  price  day  month  year arrival_hour arrival_minute
# 0  Mumbai  5,953   11      2  2022           21             05
# 1  Mumbai  5,953   11      2  2022           08             40
# 2  Mumbai  5,956   11      2  2022           06             35
# 3  Mumbai  5,955   11      2  2022           12             35
# 4  Mumbai  5,955   11      2  2022           11             10

# %%
df['arrival_hour'] = df['arrival_hour'].astype(int)
df['arrival_minute'] = df['arrival_minute'].astype(int)

# %%
df
# Out:
#          airline ch_code  num_code dep_time     from time_taken  \
# 0       SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2        AirAsia      I5       764    04:25    Delhi    02h 10m
# 3        Vistara      UK       995    10:20    Delhi    02h 15m
# 4        Vistara      UK       963    08:50    Delhi    02h 20m
# ...          ...     ...       ...      ...      ...        ...
# 206769   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773   Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     21:05     Mumbai
# ...

# %%
# drop arr_time

df.drop('arr_time', axis=1, inplace=True)

# %%
df
# Out:
#          airline ch_code  num_code dep_time     from time_taken  \
# 0       SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2        AirAsia      I5       764    04:25    Delhi    02h 10m
# 3        Vistara      UK       995    10:20    Delhi    02h 15m
# 4        Vistara      UK       963    08:50    Delhi    02h 20m
# ...          ...     ...       ...      ...      ...        ...
# 206769   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773   Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop         to  price  \
# 0                                               non-stop      Mumbai  5,953
# ...

# %%
# fix dep_time too
df['dep_hour'] = df['dep_time'].str.split(":").str[0]
df['dep_minute'] = df['dep_time'].str.split(":").str[1]
df
# Out:
#          airline ch_code  num_code dep_time     from time_taken  \
# 0       SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2        AirAsia      I5       764    04:25    Delhi    02h 10m
# 3        Vistara      UK       995    10:20    Delhi    02h 15m
# 4        Vistara      UK       963    08:50    Delhi    02h 20m
# ...          ...     ...       ...      ...      ...        ...
# 206769   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773   Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop         to  price  \
# 0                                               non-stop      Mumbai  5,953
# ...

# %%
df.drop("dep_time", axis=1, inplace=True)
df
# Out:
#          airline ch_code  num_code     from time_taken  \
# 0       SpiceJet      SG      8709    Delhi    02h 10m
# 1       SpiceJet      SG      8157    Delhi    02h 20m
# 2        AirAsia      I5       764    Delhi    02h 10m
# 3        Vistara      UK       995    Delhi    02h 15m
# 4        Vistara      UK       963    Delhi    02h 20m
# ...          ...     ...       ...      ...        ...
# 206769   Vistara      UK       832  Chennai    13h 50m
# 206770   Vistara      UK       832  Chennai    13h 50m
# 206771   Vistara      UK       826  Chennai    20h 35m
# 206772   Vistara      UK       822  Chennai    23h 20m
# 206773   Vistara      UK       824  Chennai    24h 25m
#
#                                                      stop         to  price  \
# 0                                               non-stop      Mumbai  5,953
# 1                                               non-stop      Mumbai  5,953
# ...

# %%
# convert departures to int
df['dep_hour'] = df['dep_hour'].astype(int)
df['dep_minute'] = df['dep_minute'].astype(int)

df
# Out:
#          airline ch_code  num_code     from time_taken  \
# 0       SpiceJet      SG      8709    Delhi    02h 10m
# 1       SpiceJet      SG      8157    Delhi    02h 20m
# 2        AirAsia      I5       764    Delhi    02h 10m
# 3        Vistara      UK       995    Delhi    02h 15m
# 4        Vistara      UK       963    Delhi    02h 20m
# ...          ...     ...       ...      ...        ...
# 206769   Vistara      UK       832  Chennai    13h 50m
# 206770   Vistara      UK       832  Chennai    13h 50m
# 206771   Vistara      UK       826  Chennai    20h 35m
# 206772   Vistara      UK       822  Chennai    23h 20m
# 206773   Vistara      UK       824  Chennai    24h 25m
#
#                                                      stop         to  price  \
# 0                                               non-stop      Mumbai  5,953
# 1                                               non-stop      Mumbai  5,953
# ...

# %%
df.at[206770, "stop"]
# Out:
# '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t'

# %%
df['stop'].unique()
# Out:
# array(['non-stop ',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia IXU\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Chennai\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Indore\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia RPR\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '2+-stop',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Lucknow\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia GOP\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Raipur\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Nagpur\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Surat\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia Hyderabad\n\t\t\t\t\t\t\t\t\t\t\t\t',
#        '1-stop\n\t\t\t\t\t\t\t\t\t\t\t\tVia STV\n\t\t\t\t\t\t\t\t\t\t\t\t',
# ...

# %%
df['stop'] = df['stop'].str.split("\n").str[0]
df['stop']

df['stop'].unique()
# Out:
# array(['non-stop ', '1-stop', '2+-stop'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206774 entries, 0 to 206773
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   airline         206774 non-null  object
#  1   ch_code         206774 non-null  object
#  2   num_code        206774 non-null  int64
#  3   from            206774 non-null  object
#  4   time_taken      206774 non-null  object
#  5   stop            206774 non-null  object
#  6   to              206774 non-null  object
#  7   price           206774 non-null  object
#  8   day             206774 non-null  int64
#  9   month           206774 non-null  int64
#  10  year            206774 non-null  int64
#  11  arrival_hour    206774 non-null  int64
#  12  arrival_minute  206774 non-null  int64
#  13  dep_hour        206774 non-null  int64
#  14  dep_minute      206774 non-null  int64
# dtypes: int64(8), object(7)
# memory usage: 23.7+ MB

# %%
df
# Out:
#          airline ch_code  num_code     from time_taken       stop         to  \
# 0       SpiceJet      SG      8709    Delhi    02h 10m  non-stop      Mumbai
# 1       SpiceJet      SG      8157    Delhi    02h 20m  non-stop      Mumbai
# 2        AirAsia      I5       764    Delhi    02h 10m  non-stop      Mumbai
# 3        Vistara      UK       995    Delhi    02h 15m  non-stop      Mumbai
# 4        Vistara      UK       963    Delhi    02h 20m  non-stop      Mumbai
# ...          ...     ...       ...      ...        ...        ...        ...
# 206769   Vistara      UK       832  Chennai    13h 50m     1-stop  Hyderabad
# 206770   Vistara      UK       832  Chennai    13h 50m     1-stop  Hyderabad
# 206771   Vistara      UK       826  Chennai    20h 35m     1-stop  Hyderabad
# 206772   Vistara      UK       822  Chennai    23h 20m     1-stop  Hyderabad
# 206773   Vistara      UK       824  Chennai    24h 25m     1-stop  Hyderabad
#
# ...

# %%
# categorical encoding on stops
['non-stop ', '1-stop', '2+-stop']
df['stop'] = df['stop'].map({
    'non-stop ':0, 
    '1-stop':1, 
    '2+-stop':2
})

df
# Out:
#          airline ch_code  num_code     from time_taken  stop         to  \
# 0       SpiceJet      SG      8709    Delhi    02h 10m     0     Mumbai
# 1       SpiceJet      SG      8157    Delhi    02h 20m     0     Mumbai
# 2        AirAsia      I5       764    Delhi    02h 10m     0     Mumbai
# 3        Vistara      UK       995    Delhi    02h 15m     0     Mumbai
# 4        Vistara      UK       963    Delhi    02h 20m     0     Mumbai
# ...          ...     ...       ...      ...        ...   ...        ...
# 206769   Vistara      UK       832  Chennai    13h 50m     1  Hyderabad
# 206770   Vistara      UK       832  Chennai    13h 50m     1  Hyderabad
# 206771   Vistara      UK       826  Chennai    20h 35m     1  Hyderabad
# 206772   Vistara      UK       822  Chennai    23h 20m     1  Hyderabad
# 206773   Vistara      UK       824  Chennai    24h 25m     1  Hyderabad
#
#         price  day  month  year  arrival_hour  arrival_minute  dep_hour  \
# ...
